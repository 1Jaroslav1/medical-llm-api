# %%
from datasets import load_dataset, concatenate_datasets, Dataset
import pandas as pd

# %%
d = load_dataset("atom92/medical_healthwa_all_2.0", split="train")
# Out:
# ...
# Generating train split:   0%|          | 0/52105 [00:00<?, ? examples/s]

# %%
pd.set_option('display.max_colwidth', None)

# %%
df = d.to_pandas()

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.applymap(lambda x: "Dracunculiasis" in str(x)).sum().sum()
# Out:
# /tmp/ipykernel_3043/3314400416.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: "Dracunculiasis" in str(x)).sum().sum()
# 1

# %%
rows_with_substring = df.apply(lambda col: col.str.contains("Dracunculiasis", case=False, na=False)).any(axis=1)
print(df[rows_with_substring])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
